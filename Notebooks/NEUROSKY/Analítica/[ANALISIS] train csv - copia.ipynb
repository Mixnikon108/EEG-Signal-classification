# %%
import pandas as pd
import numpy as np
pd.options.plotting.backend = "plotly"

# %%
df = pd.read_csv(r"C:/Users/Jorge/Desktop/Proyecto CDIA/Data/neuroskyData/train.csv")
df.head()
# Out:
#    label  FP1-0  FP1-1  FP1-2  FP1-3  FP1-4  FP1-5  FP1-6  FP1-7  FP1-8  ...  \
# 0      0     36     37     48     62     69     82     98     99     85  ...
# 1      2     18      6      5      9     11      9      9     15     23  ...
# 2      1     45     55     62     60     55     54     56     57     46  ...
# 3      6     23     26     23     16     12     17     29     43     49  ...
# 4      5     27     32     37     44     44     41     40     42     39  ...
#
#    FP1-1014  FP1-1015  FP1-1016  FP1-1017  FP1-1018  FP1-1019  FP1-1020  \
# 0        87        82        94       101        92        78        72
# 1        60        65        61        53        39        24        21
# 2        19        18        16         8         3        15        43
# 3        96       118       117        89        58        45        63
# 4        46        33        23        24        35        41        33
#
#    FP1-1021  FP1-1022  FP1-1023
# 0        70        63        55
# ...

# %% [markdown]
# Comprobar que los datos esten nivelados

# %%
df['label'].value_counts(normalize=True) * 100
# Out:
# -1    18.779343
#  5     8.232598
#  7     8.208569
#  8     8.199327
#  0     8.177147
#  2     8.156815
#  1     8.129089
#  6     8.095819
#  9     8.058852
#  3     8.007098
#  4     7.955344
# Name: label, dtype: float64

# %%
df.describe()
# Out:
#               label         FP1-0         FP1-1         FP1-2         FP1-3  \
# count  54102.000000  54102.000000  54102.000000  54102.000000  54102.000000
# mean       3.468282     33.866308     33.816144     33.781228     33.784315
# std        3.366031     76.621799     76.477396     76.436913     76.344590
# min       -1.000000  -2036.000000  -2024.000000  -2013.000000  -2019.000000
# 25%        0.000000     11.000000     11.000000     11.000000     12.000000
# 50%        3.000000     35.000000     35.000000     35.000000     34.000000
# 75%        6.000000     56.000000     56.000000     55.000000     55.000000
# max        9.000000   1473.000000   1503.000000   1507.000000   1496.000000
#
#               FP1-4         FP1-5         FP1-6         FP1-7         FP1-8  \
# count  54102.000000  54102.000000  54102.000000  54102.000000  54102.000000
# mean      33.787549     33.802928     33.828121     33.844886     33.897934
# ...

# %%
df_mean = df.groupby('label').mean()

# %%
df_mean.T.plot()
